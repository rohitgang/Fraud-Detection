# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('C:/Users/Rohit/Pictures/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
from sklearn.cluster import KMeans

model= KMeans(init= 'k-means++', n_clusters= 2, n_init= 7)
model.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=7, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(1, figsize= (10,6))
plt.clf()
ax = Axes3D( fig, rect = [0,0, 0.95, 1], elev= 20, azim = 50)
labels= model.labels_
plt.cla()
ax.set_xlabel('Time')
ax.set_ylabel('Amount')
ax.set_zlabel('Class')

ax.scatter(df['Time'],df['Amount'], df['Class'], c= labels.astype(np.float))
ax.legend(labels[:])

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
features= df.columns[1:29]
features
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28'],
#       dtype='object')

# %%
for i in range(len(features)):
    plt.plot(df[features[i]], df['Amount'])

# %%
for i in range(len(features)):
    plt.scatter(df[features[i]], df['Amount'], c= df['Class'])
    plt.legend()
    plt.show()

# %%
from sklearn.model_selection import train_test_split

X= df.drop('Class', axis= 1)
Y= df['Class']

x_train, x_test, y_train, y_test= train_test_split(X, Y, test_size= 0.3, random_state= 3)

# %%
from sklearn.linear_model import LinearRegression

modelLin= LinearRegression().fit(x_train, y_train)
yHat= modelLin.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

print('RMSE:', np.sqrt(mean_squared_error(yHat, y_test)))
# Out:
# RMSE: 0.028875369796845286

# %%
modelLin.coef_
# Out:
# array([-5.32921733e-09, -1.96961155e-03,  2.76988179e-03, -5.08280544e-03,
#         3.71615956e-03, -2.34371294e-03, -1.62968461e-03, -6.81388294e-03,
#         7.72111341e-04, -3.55611665e-03, -8.04399281e-03,  6.17580615e-03,
#        -1.06728505e-02, -2.09892781e-04, -1.29516230e-02, -2.79799901e-04,
#        -9.19625690e-03, -1.59470424e-02, -5.53258633e-03,  1.92404095e-03,
#         4.24139292e-04,  1.93719331e-03,  3.06176731e-04,  8.45518683e-05,
#        -5.38368836e-04,  1.72180492e-04,  3.55618615e-04,  1.59446145e-03,
#         1.19833920e-03,  6.72690829e-06])

# %%
model.fit(x_train, y_train)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=7, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(1, figsize= (10,6))
plt.clf()
ax = Axes3D( fig, rect = [0,0, 0.95, 1], elev= 20, azim = 50)
labels= model.labels_
plt.cla()
ax.set_xlabel('Time')
ax.set_ylabel('Amount')
ax.set_zlabel('Class')

ax.scatter(df['Time'],df['Amount'], df['Class'])
ax.legend(labels[:])

# %%
vals= np.array(df['Class'])
col= np.asarray(['yellow','blue'])
plt.scatter(df['Time'], df['Amount'], c= col[vals]) #, c= 'red' if df.Class==1 else 'blue')
plt.xlabel('Time')
plt.ylabel('Amount')
# Out:
# Text(0, 0.5, 'Amount')

# %%
df['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn import svm

clf= svm.SVC(kernel= 'poly')
clf.fit(x_train, y_train)
# Out:
# C:\Users\Rohit\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
